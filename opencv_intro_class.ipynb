# %%
! pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.62-cp36-abi3-win_amd64.whl (35.4 MB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\ydo16\anaconda3\lib\site-packages (from opencv-python) (1.20.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.62

# %%
import sys
import cv2
import numpy as np

print('opencv version = {}'.format(cv2.__version__))
print('numpy version = {}'.format(np.__version__))
# Out:
# opencv version = 4.5.5
# numpy version = 1.20.3

# %%
img = cv2.imread('fig/puppy.bmp',
                flags = cv2.IMREAD_COLOR)
# ret == numpy.ndarry

# print(type(img))
print('image dimension = ', img.shape)

cv2.namedWindow('image')
cv2.imshow('image', img)

key = cv2.waitKey()
# print(key)

cv2.destroyAllWindows()
# Out:
# image dimension =  (480, 640, 3)

# %%
import sys
import cv2
import numpy as np

img = cv2.imread('fig/puppy.bmp', flags = cv2.IMREAD_GRAYSCALE)

if img is None:
    print('Image read failed')
    sys.exit()

cv2.namedWindow('image')
cv2.imshow('image', img)

cv2.waitKey()

cv2.destroyAllWindows()

# %%
import sys
import cv2
import numpy as np

img = cv2.imread('fig/ddp.jpg', flags = cv2.IMREAD_COLOR)

if img is None:
    print('Image read failed')
    sys.exit()

cv2.namedWindow('image')
cv2.imshow('image', img)

cv2.waitKey()

cv2.destroyAllWindows()

# %%
img = cv2.imread('fig/ddp.jpg', cv2.IMREAD_REDUCED_GRAYSCALE_2)

if img is None:
    print('image read failed')
    sys.exit()
print(img.shape)

cv2.namedWindow('image')
cv2.imshow('image', img)
cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# (720, 540)

# %%
import sys
import cv2
import numpy as np

img = cv2.imread('fig/ddp.jpg', cv2.IMREAD_UNCHANGED)

if img is None:
    print('image read failed')
    sys.exit()
print(img.shape)

cv2.namedWindow('image')
cv2.imshow('image', img)
cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# (1440, 1080, 3)

# %%
import sys
import cv2
import numpy as np

img = cv2.imread('fig/puppy.bmp', flags = cv2.IMREAD_GRAYSCALE)

if img is None:
    print('image read failed')
    sys.exit()

print(img.shape)

img_re = cv2.resize(img, (240, 320), interpolation = cv2.INTER_AREA)
img_re2 = cv2.resize(img, (320, 240), interpolation = cv2.INTER_AREA)

cv2.namedWindow('image')
# cv2.namedWindow('image_re')
cv2.namedWindow('image_re2')

cv2.imshow('image', img)
# cv2.imshow('image_re', img_re)
cv2.imshow('image_re2', img_re2)

cv2.imwrite('puppy_resize.png', img_re2)

cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# (480, 640)

# %%
img = cv2.imread('fig/puppy.bmp', cv2.IMREAD_COLOR)
# img_re = cv2.resize(img, (320, 240), cv2.INTER_AREA)

if img is None:
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('image', cv2.WINDOW_AUTOSIZE)
# cv2.namedWindow('image', cv2.WINDOW_NORMAL)
# cv2.moveWindow('image', 400, 100)

cv2.imshow('image', img)
# cv2.imshow('image_re', img_re)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
img = cv2.imread('fig/puppy.bmp', cv2.IMREAD_COLOR)

if img is None:
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('image')
cv2.imshow('image', img)

while True:
    if cv2.waitKey() == ord('q'):
        break

# ASKII 코드를 받아서 출력
# key = cv2.waitKey(3000)
# print(key)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28328/195116251.py in <module>
#       9
#      10 while True:
# ---> 11     if cv2.waitKey() == ord('q'):
#      12         break
#      13
#
# KeyboardInterrupt:

# %%
img = cv2.imread('fig/puppy.bmp', cv2.IMREAD_COLOR)

if img is None:
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('image')
cv2.imshow('image', img)

while True:
    key = cv2.waitKey()
    if key == 27 or key == ord('q'):
        break

cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
import sys
import cv2
import numpy as np

# %%
# BGR
img = cv2.imread('fig/puppy.bmp', cv2.IMREAD_COLOR)

if img is None:
    print('image read failed')
    sys.exit()
    
# cv2.namedWindow('image')
# cv2.imshow('image', img)

# RGB
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize = (12, 6))
plt.subplot(131), plt.imshow(img), plt.axis('off')
plt.subplot(132), plt.imshow(imgRGB), plt.axis('off')
plt.subplot(133), plt.imshow(imgGray, cmap = 'gray'), plt.axis('off')
plt.show()

plt.imshow(imgGray, cmap = 'gray')
plt.axis('off') 
plt.show()

# while True:
#     key = cv2.waitKey()
#     if key == 27:
#         break
        
# cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7724/2471110701.py in <module>
#      24
#      25 while True:
# ---> 26     key = cv2.waitKey()
#      27     if key == 27:
#      28         break
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import sys
import cv2
import numpy as np
import os

# %%
img_list = os.listdir('fig/images/')

# print(img_list)

img_path = []
for i in img_list:
    img_path_all = 'fig/images/' + i
    img_path.append(img_path_all)
    
# img_path

cv2.namedWindow('image', cv2.WINDOW_NORMAL)
# cv2.setWindowProperty('image', cv2.WND_PROP_FULLSCREEN,
#                      cv2.WINDOW_FULLSCREEN)

# for i in img_path:
#     img = cv2.imread(i, cv2.IMREAD_COLOR)
    
#     cv2.imshow('image', img)
    
#     cv2.waitKey(20000)

idx = 0    
while True:
    img_name = img_path[idx]
    img = cv2.imread(img_name, cv2.IMREAD_COLOR)
    
    cv2.imshow('image', img)
    
    cv2.waitKey(2000)

    if cv2.waitKey(1000) == 27: #ESC
        break
    
    idx += 1
    
    if idx >= len(idx):
        idx = 0
        
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17864/3573490252.py in <module>
#      35     idx += 1
#      36
# ---> 37     if idx >= len(idx):
#      38         idx = 0
#      39
#
# TypeError: object of type 'int' has no len()
